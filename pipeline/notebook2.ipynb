# %%
# !uv add pandas sqlalchemy psycopg2 tqdm
# Out:
# Resolved 119 packages in 0.64ms
# Audited 10 packages in 0.19ms

# %%
import pandas as pd

# %%
df_zones = pd.read_csv('https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv')
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
from sqlalchemy import create_engine
engine=create_engine('postgresql://admin:root@localhost:5432/ny_taxi')
engine
# Out:
# Engine(postgresql://admin:***@localhost:5432/ny_taxi)

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265

# %%
len(df_zones)
# Out:
# 265
